# %%
# !pip install streamlit
# !pip install folium
# !pip install geopandas
import streamlit as st
import pandas as pd
import numpy as np
import folium
import streamlit.components.v1 as components
import json
import geopandas as gpd
from branca.element import Template, MacroElement
from template import template

# !pip install ipykernel>=5.1.2
# !pip install pydeck

from branca.element import Template, MacroElement

#!streamlit run /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py

from branca.element import Template, MacroElement
from template import template
import branca.colormap as cm
st.header("Antyodaya Dashboard Rajasthan")

# Base Map##put centre of centriod of rajesthan
m = folium.Map(location=[26.5844, 73.8496],zoom_start=6, tiles='cartodbpositron')

# Reading state Data
df = pd.read_csv("raj_dist_ma.csv")
geoData = open('raj_dist_ma_dash.json', 'r')

# Reading ac data
geo_ac_data = gpd.read_file("raj_ac_ma_dash.json")
districts = list(geo_ac_data['District'].unique())
districts.insert(0, "All")
ac_df = pd.read_csv('raj_ac_ma.csv')

# Reading gc data
geo_gc_data = gpd.read_file("raj_gp_ma_dash.json")


# Creating dropdowns
category = st.sidebar.selectbox("Select a Category", list(df.columns[4:34]))
district = st.sidebar.selectbox("Select a District", districts)

# Function to calculate opacity
def calculate_opacity(df, category, i):
    colors = ['#F1EEF6', '#D4B9DA', '#C994C7',
                        '#DF65B0', '#E7298A', '#CE1256', '#91003F']
    temp = list(df[category])
    try:
        op = (temp[i] - min(temp)) / (max(temp) - min(temp))
        if op <= 1 and op > 0.75:
            return colors[1]
        elif op <= 0.75 and op > 0.5:
            return colors[2]
        elif op <= 0.5 and op > 0.25:
            return  colors[4]
        else:
            return colors[6]
        # if op <= 1 and op > 0.833:
        #     return colors[6]
        # elif op <= 0.833 and op > 0.666:
        #     return colors[5]
        # elif op <= 0.666 and op > 0.499:
        #     return  colors[4]
        # elif op <= 0.499 and op > 0.332:
        #     return colors[3]
        # elif op <= 0.332 and op > 0.165:
        #     return  colors[2]
        # else:
        #     return colors[1]

    except:
        return colors[1]

if district == "All":

    choropleth = folium.Choropleth(
        geo_data=json.load(geoData),
        name='choropleth',
        data=df,
        columns=['District Name', str(category)],
        key_on='feature.properties.District Name',
        fill_color='YlGnBu',
        fill_opacity=0.9,
        line_opacity=1,
        legend_name=str(category)
    ).add_to(m)

    # folium.LayerControl().add_to(m)
    choropleth.geojson.add_child(
    folium.features.GeoJsonTooltip(
                fields=['District Name', str(category)],
                aliases=['District:', str(category)+":"],
                style=("background-color: white; color: #333333; font-family: arial; font-size: 12px; padding: 10px;")))

    m.save('map2.html')
    HtmlFile = open("map2.html", 'r', encoding='utf-8')
    source_code = HtmlFile.read()
    HtmlFile.close()

    # Showing map in streamlit
    components.html(source_code,width=700, height=500)

else:
    new_geo_gc_data = geo_gc_data[geo_gc_data['District'] == str(district)]

    assembly_constituencies = list(new_geo_gc_data['Assembly Constituency'].unique())
    assembly_constituencies.insert(0, "None")

# %%
geo_gc_data['Assembly Constituency'].unique()
# Out:
# array(['Ajmer North(504)', 'Beawar(672)', 'Kekri(507)', 'Kishangarh(508)',
#        'Masuda(509)', 'Nasirabad(510)', 'Pushkar(511)',
#        'Alwar Rural(512)', 'Bansur(601)', 'Alwar urban(513)',
#        'Ramgarh(518)', 'Behror(514)', 'Mundawar(516)', 'Kathumar(540)',
#        'Kishangarh bas(515)', 'Rajgarh laxmangarh(517)', 'Thanagazi(583)',
#        'Tijara(519)', 'Bagidora(520)', 'Banswara(521)', 'Ghatol(525)',
#        'Garhi(524)', 'Kushalgarh(526)', 'Anta(616)', 'Baran-atru(617)',
#        'Chhabra(618)', 'Kishanganj(622)', 'Malviya Nagar(597)',
#        'Barmer(528)', 'Baytoo(529)', 'Chohtan(530)', 'Gudhamalani(531)',
#        'Pachpadra(533)', 'Sheo(534)', 'Siwana(535)', 'Bayana(536)',
#        'Bharatpur(537)', 'Deeg-kumher(538)', 'Kaman(539)', 'Nadbai(541)',
#        'Nagar(542)', 'Weir(543)', 'Asind(544)', 'Bhilwara(545)',
#        'Mandal(548)', 'Jahazpur(547)', 'Mandalgarh(549)', 'Sahara(550)',
#        'Shahpura(551)', 'Bikaner East(553)', 'Lunkaransar(558)',
#        'Dungargarh(555)', 'Khajuwala(556)', 'Kolayat(557)', 'Nokha(559)',
#        'Bundi(648)', 'Hindoli(546)', 'Keshoraipatan(649)',
#        'Bari sadri(560)', 'Begun(561)', 'Chittorgarh(562)',
#        'Kapasan(563)', 'Nimbahera(565)', 'Churu(569)', 'Ratangarh(571)',
#        'Sardarshahar(573)', 'Sadulpur(572)', 'Sujangarh(574)',
#        'Taranagar(575)', 'Bandikui(576)', 'Dausa(579)', 'Lalsot(580)',
#        'Mahuwa(581)', 'Sikrai(582)', 'Bari(640)', 'Baseri(641)',
#        'Dholpur(642)', 'Rajakhera(645)', 'Aspur(696)', 'Sagwara(527)',
#        'Chorasi(522)', 'Dungarpur(523)', 'Anupgarh(552)',
#        'Raisingh Nagar(588)', 'Ganganagar(584)', 'Sadulshahar(589)',
#        'Karanpur(586)', 'Suratgarh(591)', 'Bhadra(568)',
#        'Hanumangarh(585)', 'Sangaria(590)', 'Nohar(570)',
#        'Pilibanga(587)', 'Adarsh Nagar(592)', 'Amber(600)', 'Bagru(593)',
#        'Dudu(506)', 'Bassi(577)', 'Chaksu(578)', 'Chomu(680)',
#        'Hawa mahal(595)', 'Jamwa ramgarh(602)', 'Jhotwara(603)',
#        'Kotputli(604)', 'Phulera(605)', 'Sanganer(598)', 'Shahpura(606)',
#        'Viratnagar(607)', 'Jaisalmer(532)', 'Pokaran(636)', 'Ahore(608)',
#        'Sirohi(615)', 'Jalore(610)', 'Bhinmal(609)', 'Raniwara(612)',
#        'Sanchore(614)', 'Dag(619)', 'Jhalrapatan(620)', 'Khanpur(621)',
#        'Manohar thana(623)', 'Jhunjhunu(625)', 'Khetri(626)',
#        'Surajgarh(630)', 'Mandawa(627)', 'Nawalgarh(628)', 'Pilani(629)',
#        'Udaipurwati(631)', 'Bhopalgarh(665)', 'Bilara(666)',
#        'Jodhpur(632)', 'Lohawat(633)', 'Luni(634)', 'Osian(668)',
#        'Phalodi(635)', 'Shergarh(638)', 'Hindaun(643)', 'Todabhim(647)',
#        'Karauli(644)', 'Sapotra(646)', 'Kota South(651)', 'Pipalda(653)',
#        'Ladpura(652)', 'Ramganj mandi(654)', 'Sangod(655)', 'Bhim(673)',
#        'Deedwana(656)', 'Ladnun(659)', 'Degana(674)', 'Jayal(657)',
#        'Khinwsar(658)', 'Makrana(660)', 'Merta(677)', 'Nagaur(661)',
#        'Nawan(662)', 'Parbatsar(663)', 'Bali(664)', 'Jaitaran(675)',
#        'Marwar junction(667)', 'Pali(669)', 'Sumerpur(671)', 'Sojat(670)',
#        'Dhariawad(697)', 'Pratapgarh(566)', 'Kumbhalgarh(676)',
#        'Rajsamand(679)', 'Nathdwara(678)', 'Bamanwas(688)',
#        'Gangapur(690)', 'Khandar(691)', 'Sawai madhopur(694)',
#        'Tonk(695)', 'Danta ramgarh(681)', 'Dhod(682)', 'Fatehpur(624)',
#        'Khandela(683)', 'Lachhmangarh(684)', 'Neem ka thana(685)',
#        'Sikar(686)', 'Srimadhopur(687)', 'Pindwara abu(611)',
#        'Reodar(613)', 'Deoli - uniara(689)', 'Malpura(692)', 'Niwai(693)',
#        'Gogunda(698)', 'Udaipur Rural(703)', 'Jhadol(699)',
#        'Kherwara(700)', 'Mavli(564)', 'Salumber(701)', 'Udaipur(702)',
#        'Vallabh Nagar(567)'], dtype=object)

# %%
new_geo_gc_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/2y/43tdd9hn3g11897s6jjnr8840000gn/T/ipykernel_34278/2131028118.py in <module>
# ----> 1 new_geo_gc_data
#
# NameError: name 'new_geo_gc_data' is not defined
